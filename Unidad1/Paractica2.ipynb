# %% [markdown]
# <a href="https://colab.research.google.com/github/SludgeDanny/Probabilidad-y-Estad-stica/blob/main/Unidad1/Paractica2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Unidad1
##**Practica 2: Maximo, minimo, rango y dispersión de datos**
###Facilitador: Jose Gabriel Rodriguez Rivas
###Alumno: Daniel Rosales Reyes

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
fabrica1 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(50,100), 2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [81.61, 55.02, 61.6, 75.28, 73.59, 55.97, 69.01, 95.63, 61.72, 79.01, 87.92, 78.7, 53.66, 57.13, 91.93, 51.65, 74.56, 56.44, 65.51, 67.08, 50.01, 72.42, 54.13, 96.38, 82.21, 71.74, 68.4, 54.92, 55.45, 95.2, 89.85, 86.39, 58.06, 74.4, 74.66, 79.27, 67.88, 76.92, 60.03, 98.86, 92.26, 52.21, 67.23, 51.05, 57.65, 50.21, 80.99, 75.39, 58.39, 75.37, 57.45, 59.0, 87.94, 85.6, 64.97, 83.92, 75.79, 80.2, 85.46, 94.74, 92.17, 55.46, 91.46, 71.02, 57.22, 85.38, 52.85, 55.58, 69.05, 60.22, 79.68, 55.74, 76.12, 95.2, 73.87, 71.48, 89.04, 71.1, 97.27, 53.26, 56.01, 87.54, 71.77, 67.45, 79.7, 92.68, 70.65, 60.8, 91.9, 87.48, 79.89, 76.15, 81.06, 51.79, 91.76, 84.34, 69.5, 78.86, 76.45, 85.85]

# %%
fabrica2 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(50,100), 2)
  fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [89.53, 97.52, 97.75, 70.52, 69.33, 94.48, 72.09, 99.37, 64.26, 65.81, 76.97, 65.08, 98.74, 50.29, 66.03, 78.01, 89.53, 88.65, 71.68, 53.49, 96.34, 94.32, 83.82, 72.12, 86.71, 96.42, 78.54, 94.09, 74.39, 61.69, 53.05, 80.33, 79.39, 78.85, 61.49, 87.59, 88.28, 58.96, 51.26, 90.71, 56.89, 78.08, 52.87, 50.37, 61.51, 53.93, 67.2, 82.2, 71.94, 55.38, 69.41, 78.84, 96.01, 62.84, 87.26, 50.94, 73.15, 57.71, 74.72, 76.52, 51.0, 85.86, 75.22, 73.13, 85.1, 97.26, 54.88, 58.38, 92.74, 90.32, 68.18, 64.74, 72.46, 63.09, 62.56, 98.59, 85.21, 94.91, 53.03, 67.74, 77.03, 53.33, 90.32, 85.65, 95.29, 96.67, 80.27, 95.65, 85.39, 99.75, 79.45, 50.95, 87.69, 86.09, 69.01, 90.73, 79.51, 75.13, 93.81, 65.66]

# %% [markdown]
# #Maximo, mínimo y rango

# %%
maximo1 = max(fabrica1)
minimo1 = min(fabrica1)
rango1 = maximo1 - minimo1
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)
desviacion_estandar_fabrica1 = stdev(fabrica1)
print("Estadisrica escriptiva de la Fabrica 1 \n", "Media = ", media1, "\n Mediana = ", mediana1, "\n Moda = ", moda1,"\n Maximo = ", maximo1, "\n Minimo = ", minimo1, "\n Rango = ", rango1)
print(desviacion_estandar_fabrica1)
# Out:
# Estadisrica escriptiva de la Fabrica 1
#  Media =  72.9082
#  Mediana =  74.135
#  Moda =  95.2
#  Maximo =  98.86
#  Minimo =  50.01
#  Rango =  48.85
# 13.95001613843605

# %%
maximo2 = max(fabrica2)
minimo2 = min(fabrica2)
rango2 = maximo1 - minimo1
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)
desviacion_estandar_fabrica2 = stdev(fabrica2)
print("Estadisrica escriptiva de la Fabrica 2 \n", "Media = ", media2, "\n Mediana = ", mediana2, "\n Moda = ", moda2,"\n Maximo = ", maximo2, "\n Minimo = ", minimo2, "\n Rango = ", rango2)
print(desviacion_estandar_fabrica2)
# Out:
# Estadisrica escriptiva de la Fabrica 2
#  Media =  76.1703
#  Mediana =  77.0
#  Moda =  89.53
#  Maximo =  99.75
#  Minimo =  50.29
#  Rango =  48.85
# 14.933505914519534

# %%
from matplotlib.lines import lineStyles
plt.figure(figsize=(8,6))
plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label =f'Media={media1:.2f}')
plt.axvline(mediana1, color='r', linestyle = 'dashed', linewidth=2, label =f'Mediana={mediana1:.2f}')
plt.axvline(moda1, color='g', linestyle = 'dashed', linewidth=2, label =f'Moda={moda1:.2f}')
plt.axvline(desviacion_estandar_fabrica1, color='black', linestyle = 'dashed', linewidth=2, label=f'Devs.Estandar = {desviacion_estandar_fabrica1:.2f}')
plt.axvline(media1 + desviacion_estandar_fabrica1, color='black', linestyle = 'dashed', linewidth=2)

plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la Fabrica 1")
plt.legend()
plt.show()

# %%
from matplotlib.lines import lineStyles
plt.figure(figsize=(8,6))
plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label =f'Media={media2:.2f}')
plt.axvline(mediana2, color='r', linestyle = 'dashed', linewidth=2, label =f'Mediana={mediana2:.2f}')
plt.axvline(moda2, color='g', linestyle = 'dashed', linewidth=2, label =f'Moda={moda2:.2f}')
plt.axvline(desviacion_estandar_fabrica2, color='black', linestyle = 'dashed', linewidth=2, label=f'Devs.Estandar = {desviacion_estandar_fabrica2:.2f}')
plt.axvline(media2 + desviacion_estandar_fabrica2, color='black', linestyle = 'dashed', linewidth=2)

plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la Fabrica 2")
plt.legend()
plt.show()

# %%
import seaborn as sns
#La densidad gráfica es una forma de visualiza la distribución de datos en
#un intervalo o periodo de tiempo continuo.
#Se bbasa en un histoggrama que usa el suavisado de kernel para trazar valores,
#lo que permite obtener distribuciones más suaves al reducir el ruido.
#Una curva de densidad muestra la ubicaión de la mmedia y la mediana de una distribución

sns.histplot(x=fabrica1, kde = True, kde_kws = {'bw_adjust': 0.5}, bins = 10)
# Out:
# <Axes: ylabel='Count'>
