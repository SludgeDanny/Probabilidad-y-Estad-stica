# %% [markdown]
# <a href="https://colab.research.google.com/github/SludgeDanny/Probabilidad-y-Estad-stica/blob/main/Unidad1/Paractica2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Unidad1
##**Practica 2: Maximo, minimo, rango y dispersión de datos**
###Facilitador: Jose Gabriel Rodriguez Rivas
###Alumno: Daniel Rosales Reyes

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
fabrica1 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(50,100), 2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [52.97, 84.35, 96.52, 63.92, 87.22, 74.66, 67.99, 65.93, 53.22, 92.46, 99.89, 50.77, 69.98, 53.64, 94.78, 56.04, 97.09, 85.07, 89.79, 50.43, 93.54, 52.96, 81.1, 55.41, 95.8, 88.2, 77.57, 75.3, 97.77, 66.39, 75.41, 78.6, 95.87, 65.81, 93.02, 59.5, 82.86, 57.83, 95.62, 61.85, 61.2, 66.72, 87.93, 51.38, 69.52, 74.75, 85.84, 57.72, 76.61, 64.74, 80.46, 69.47, 86.38, 61.37, 62.7, 53.28, 68.33, 72.03, 64.51, 78.86, 54.66, 90.3, 69.51, 71.36, 88.61, 94.89, 64.52, 87.06, 92.03, 53.49, 89.76, 81.16, 91.99, 51.66, 97.09, 78.38, 63.46, 70.88, 71.6, 82.9, 60.16, 79.58, 89.61, 91.59, 78.48, 94.22, 84.76, 75.47, 61.46, 56.11, 73.1, 73.46, 72.42, 51.78, 51.35, 87.95, 99.66, 54.99, 75.96, 57.99]

# %%
fabrica2 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(50,100), 2)
  fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [83.73, 67.26, 80.18, 60.75, 92.43, 59.32, 78.78, 74.31, 81.28, 93.45, 75.24, 62.5, 56.59, 62.05, 99.67, 54.95, 88.77, 57.63, 72.95, 60.6, 98.63, 94.72, 91.68, 58.61, 76.96, 85.63, 72.2, 94.92, 58.86, 96.53, 54.12, 79.03, 97.71, 80.34, 66.07, 79.12, 55.07, 55.38, 93.99, 74.75, 95.62, 77.64, 90.91, 64.44, 66.2, 98.88, 74.93, 78.88, 54.19, 54.35, 95.63, 88.17, 77.6, 95.17, 53.54, 56.55, 59.98, 70.82, 62.08, 95.16, 50.63, 85.1, 60.38, 80.28, 89.33, 98.21, 98.99, 50.6, 82.13, 78.9, 60.59, 68.14, 90.63, 58.26, 92.64, 91.46, 61.75, 75.58, 72.51, 99.76, 80.36, 60.53, 88.26, 66.39, 71.86, 86.11, 62.75, 57.05, 72.42, 84.27, 52.84, 70.82, 99.52, 80.45, 92.97, 63.19, 83.05, 99.61, 66.98, 78.05]

# %% [markdown]
# #Maximo, mínimo y rango

# %%
maximo1 = max(fabrica1)
minimo1 = min(fabrica1)
rango1 = maximo1 - minimo1
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)
desviacion_estandar_fabrica1 = stdev(fabrica1)
print("Estadisrica escriptiva de la Fabrica 1 \n", "Media = ", media1, "\n Mediana = ", mediana1, "\n Moda = ", moda1,"\n Maximo = ", maximo1, "\n Minimo = ", minimo1, "\n Rango = ", rango1)
print(desviacion_estandar_fabrica1)
# Out:
# Estadisrica escriptiva de la Fabrica 1
#  Media =  74.68185
#  Mediana =  74.095
#  Moda =  97.09
#  Maximo =  99.89
#  Minimo =  50.05
#  Rango =  49.84
# 14.50421838058357

# %%
maximo2 = max(fabrica2)
minimo2 = min(fabrica2)
rango2 = maximo1 - minimo1
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)
desviacion_estandar_fabrica2 = stdev(fabrica2)
print("Estadisrica escriptiva de la Fabrica 2 \n", "Media = ", media2, "\n Mediana = ", mediana2, "\n Moda = ", moda2,"\n Maximo = ", maximo2, "\n Minimo = ", minimo2, "\n Rango = ", rango2)
print(desviacion_estandar_fabrica2)
# Out:
# Estadisrica escriptiva de la Fabrica 2
#  Media =  76.0085
#  Mediana =  77.28
#  Moda =  70.82
#  Maximo =  99.76
#  Minimo =  50.6
#  Rango =  49.84
# 14.94666175864272
