# %% [markdown]
# <a href="https://colab.research.google.com/github/SludgeDanny/Probabilidad-y-Estad-stica/blob/main/Unidad1/Paractica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Practica 3
# ##**Tablas de frecuencias**
# ###Facilitador: Jose Gabriel Rodriguez Rivas
# ###Alumno: Daniel Rosales Reyes

# %%
#basado en el LIBRO estadisrica para la administración pagina 12
#creamos una lista vacia que representa la edad de 100 peronas
import random
edades = []
#Hacemos un ciclo para generar 100 nummros aleatorios que representan la edad de las personas
for i in range(100):
  #generamos un numero aleatorio con la función randint y lo guardamos en la variable numero_aleatorio
  numero_aleatorio = random.randint(18, 70)
  #Agregamos el numero aleatorio a la lista de valores
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [21, 20, 28, 34, 47, 19, 26, 46, 64, 60, 31, 33, 51, 38, 58, 56, 42, 23, 39, 22, 67, 67, 64, 33, 36, 61, 67, 28, 53, 62, 45, 43, 36, 55, 34, 35, 56, 59, 18, 69, 46, 21, 55, 37, 68, 42, 18, 66, 23, 70, 66, 40, 50, 57, 32, 30, 19, 44, 21, 57, 60, 63, 68, 38, 68, 36, 19, 70, 49, 66, 60, 50, 45, 61, 69, 31, 48, 68, 45, 40, 69, 34, 22, 46, 54, 41, 31, 49, 19, 35, 65, 61, 40, 35, 48, 25, 62, 54, 33, 36]

# %%
import pandas as pd

# %%
#Crear un Dataframe de pandas con los números aleatorios -
df = pd.DataFrame(edades, columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    21
# 1    20
# 2    28
# 3    34
# 4    47

# %%
#Calcular la tabla e distribución de frecuencias
tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')

#Imprimir la tabla de distribución de frecuencias
print("Tabla de Distribución de Frecuencias:")
tabla_frecuencias
# Out:
# Tabla de Distribución de Frecuencias:
#     Edad  Frecuencia
# 26    18           2
# 0     19           4
# 32    20           1
# 3     21           3
# 27    22           2
# 31    23           2
# 48    25           1
# 36    26           1
# 25    28           2
# 43    30           1
# 5     31           3
# 42    32           1
# 6     33           3
# 4     34           3
# 12    35           3
# 2     36           4
# 41    37           1
# 22    38           2
# 37    39           1
# 15    40           3
# 46    41           1
# 24    42           2
# 39    43           1
# 45    44           1
# 9     45           3
# 7     46           3
# 35    47           1
# 20    48           2
# 19    49           2
# 28    50           2
# 34    51           1
# 40    53           1
# 17    54           2
# 30    55           2
# 23    56           2
# 18    57           2
# 33    58           1
# 38    59           1
# 8     60           3
# 14    61           3
# 29    62           2
# 44    63           1
# 16    64           2
# 47    65           1
# 10    66           3
# 13    67           3
# 1     68           4
# 11    69           3
# 21    70           2

# %%
tabla_frecuencias['Frec Relativa'] = tabla_frecuencias['Frecuencia'] / 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa
# 26    18           2           0.02
# 0     19           4           0.04
# 32    20           1           0.01
# 3     21           3           0.03
# 27    22           2           0.02
# 31    23           2           0.02
# 48    25           1           0.01
# 36    26           1           0.01
# 25    28           2           0.02
# 43    30           1           0.01
# 5     31           3           0.03
# 42    32           1           0.01
# 6     33           3           0.03
# 4     34           3           0.03
# 12    35           3           0.03
# 2     36           4           0.04
# 41    37           1           0.01
# 22    38           2           0.02
# 37    39           1           0.01
# 15    40           3           0.03
# 46    41           1           0.01
# 24    42           2           0.02
# 39    43           1           0.01
# 45    44           1           0.01
# 9     45           3           0.03
# 7     46           3           0.03
# 35    47           1           0.01
# 20    48           2           0.02
# 19    49           2           0.02
# 28    50           2           0.02
# 34    51           1           0.01
# 40    53           1           0.01
# 17    54           2           0.02
# 30    55           2           0.02
# 23    56           2           0.02
# 18    57           2           0.02
# 33    58           1           0.01
# 38    59           1           0.01
# 8     60           3           0.03
# 14    61           3           0.03
# 29    62           2           0.02
# 44    63           1           0.01
# 16    64           2           0.02
# 47    65           1           0.01
# 10    66           3           0.03
# 13    67           3           0.03
# 1     68           4           0.04
# 11    69           3           0.03
# 21    70           2           0.02

# %%
tabla_frecuencias['Frec Porcentual'] = tabla_frecuencias['Frecuencia'] / 100 * 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual
# 26    18           2           0.02              2.0
# 0     19           4           0.04              4.0
# 32    20           1           0.01              1.0
# 3     21           3           0.03              3.0
# 27    22           2           0.02              2.0
# 31    23           2           0.02              2.0
# 48    25           1           0.01              1.0
# 36    26           1           0.01              1.0
# 25    28           2           0.02              2.0
# 43    30           1           0.01              1.0
# 5     31           3           0.03              3.0
# 42    32           1           0.01              1.0
# 6     33           3           0.03              3.0
# 4     34           3           0.03              3.0
# 12    35           3           0.03              3.0
# 2     36           4           0.04              4.0
# 41    37           1           0.01              1.0
# 22    38           2           0.02              2.0
# 37    39           1           0.01              1.0
# 15    40           3           0.03              3.0
# 46    41           1           0.01              1.0
# 24    42           2           0.02              2.0
# 39    43           1           0.01              1.0
# 45    44           1           0.01              1.0
# 9     45           3           0.03              3.0
# 7     46           3           0.03              3.0
# 35    47           1           0.01              1.0
# 20    48           2           0.02              2.0
# 19    49           2           0.02              2.0
# 28    50           2           0.02              2.0
# 34    51           1           0.01              1.0
# 40    53           1           0.01              1.0
# 17    54           2           0.02              2.0
# 30    55           2           0.02              2.0
# 23    56           2           0.02              2.0
# 18    57           2           0.02              2.0
# 33    58           1           0.01              1.0
# 38    59           1           0.01              1.0
# 8     60           3           0.03              3.0
# 14    61           3           0.03              3.0
# 29    62           2           0.02              2.0
# 44    63           1           0.01              1.0
# 16    64           2           0.02              2.0
# 47    65           1           0.01              1.0
# 10    66           3           0.03              3.0
# 13    67           3           0.03              3.0
# 1     68           4           0.04              4.0
# 11    69           3           0.03              3.0
# 21    70           2           0.02              2.0

# %%
tabla_frecuencias['Frec Acumulada'] = tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual  Frec Acumulada
# 26    18           2           0.02              2.0               2
# 0     19           4           0.04              4.0               6
# 32    20           1           0.01              1.0               7
# 3     21           3           0.03              3.0              10
# 27    22           2           0.02              2.0              12
# 31    23           2           0.02              2.0              14
# 48    25           1           0.01              1.0              15
# 36    26           1           0.01              1.0              16
# 25    28           2           0.02              2.0              18
# 43    30           1           0.01              1.0              19
# 5     31           3           0.03              3.0              22
# 42    32           1           0.01              1.0              23
# 6     33           3           0.03              3.0              26
# 4     34           3           0.03              3.0              29
# 12    35           3           0.03              3.0              32
# 2     36           4           0.04              4.0              36
# 41    37           1           0.01              1.0              37
# 22    38           2           0.02              2.0              39
# 37    39           1           0.01              1.0              40
# 15    40           3           0.03              3.0              43
# 46    41           1           0.01              1.0              44
# 24    42           2           0.02              2.0              46
# 39    43           1           0.01              1.0              47
# 45    44           1           0.01              1.0              48
# 9     45           3           0.03              3.0              51
# 7     46           3           0.03              3.0              54
# 35    47           1           0.01              1.0              55
# 20    48           2           0.02              2.0              57
# 19    49           2           0.02              2.0              59
# 28    50           2           0.02              2.0              61
# 34    51           1           0.01              1.0              62
# 40    53           1           0.01              1.0              63
# 17    54           2           0.02              2.0              65
# 30    55           2           0.02              2.0              67
# 23    56           2           0.02              2.0              69
# 18    57           2           0.02              2.0              71
# 33    58           1           0.01              1.0              72
# 38    59           1           0.01              1.0              73
# 8     60           3           0.03              3.0              76
# 14    61           3           0.03              3.0              79
# 29    62           2           0.02              2.0              81
# 44    63           1           0.01              1.0              82
# 16    64           2           0.02              2.0              84
# 47    65           1           0.01              1.0              85
# 10    66           3           0.03              3.0              88
# 13    67           3           0.03              3.0              91
# 1     68           4           0.04              4.0              95
# 11    69           3           0.03              3.0              98
# 21    70           2           0.02              2.0             100

# %%
#Importamos la libreria math de funciones matematicas
import math

# %%
#Volvemos a usar la lista edades
print(edades)
# Out:
# [21, 20, 28, 34, 47, 19, 26, 46, 64, 60, 31, 33, 51, 38, 58, 56, 42, 23, 39, 22, 67, 67, 64, 33, 36, 61, 67, 28, 53, 62, 45, 43, 36, 55, 34, 35, 56, 59, 18, 69, 46, 21, 55, 37, 68, 42, 18, 66, 23, 70, 66, 40, 50, 57, 32, 30, 19, 44, 21, 57, 60, 63, 68, 38, 68, 36, 19, 70, 49, 66, 60, 50, 45, 61, 69, 31, 48, 68, 45, 40, 69, 34, 22, 46, 54, 41, 31, 49, 19, 35, 65, 61, 40, 35, 48, 25, 62, 54, 33, 36]

# %%
#Crear un DataFrame con las edades
df = pd.DataFrame(edades, columns=['Edad'])
df
# Out:
#     Edad
# 0     21
# 1     20
# 2     28
# 3     34
# 4     47
# ..   ...
# 95    25
# 96    62
# 97    54
# 98    33
# 99    36
#
# [100 rows x 1 columns]

# %%
#Calcular el númmero de intervalos utilizando la regla de Sturges
n =len(edades)
K = int(1 + math.log2(n))
print("Valor de n = ", n, "\nNumero de intervalos =", K)
# Out:
# Valor de n =  100
# Numero de intervalos = 7

# %%
#Crear la tabla de frecuencia

tabla_frecuencia = pd.cut(df['Edad'], bins=K).value_counts().reset_index()
tabla_frecuencia.columns = ['Clase', 'Frec']
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual  Frec Acumulada
# 26    18           2           0.02              2.0               2
# 0     19           4           0.04              4.0               6
# 32    20           1           0.01              1.0               7
# 3     21           3           0.03              3.0              10
# 27    22           2           0.02              2.0              12
# 31    23           2           0.02              2.0              14
# 48    25           1           0.01              1.0              15
# 36    26           1           0.01              1.0              16
# 25    28           2           0.02              2.0              18
# 43    30           1           0.01              1.0              19
# 5     31           3           0.03              3.0              22
# 42    32           1           0.01              1.0              23
# 6     33           3           0.03              3.0              26
# 4     34           3           0.03              3.0              29
# 12    35           3           0.03              3.0              32
# 2     36           4           0.04              4.0              36
# 41    37           1           0.01              1.0              37
# 22    38           2           0.02              2.0              39
# 37    39           1           0.01              1.0              40
# 15    40           3           0.03              3.0              43
# 46    41           1           0.01              1.0              44
# 24    42           2           0.02              2.0              46
# 39    43           1           0.01              1.0              47
# 45    44           1           0.01              1.0              48
# 9     45           3           0.03              3.0              51
# 7     46           3           0.03              3.0              54
# 35    47           1           0.01              1.0              55
# 20    48           2           0.02              2.0              57
# 19    49           2           0.02              2.0              59
# 28    50           2           0.02              2.0              61
# 34    51           1           0.01              1.0              62
# 40    53           1           0.01              1.0              63
# 17    54           2           0.02              2.0              65
# 30    55           2           0.02              2.0              67
# 23    56           2           0.02              2.0              69
# 18    57           2           0.02              2.0              71
# 33    58           1           0.01              1.0              72
# 38    59           1           0.01              1.0              73
# 8     60           3           0.03              3.0              76
# 14    61           3           0.03              3.0              79
# 29    62           2           0.02              2.0              81
# 44    63           1           0.01              1.0              82
# 16    64           2           0.02              2.0              84
# 47    65           1           0.01              1.0              85
# 10    66           3           0.03              3.0              88
# 13    67           3           0.03              3.0              91
# 1     68           4           0.04              4.0              95
# 11    69           3           0.03              3.0              98
# 21    70           2           0.02              2.0             100

# %%
#Ordenar la tabla de frecuencia por el intervalo
tabla_frecuencia.columns = ['Clase', 'Frec']
tabla_frecuencia = tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 2  (17.948, 25.429]    15
# 6  (25.429, 32.857]     8
# 0  (32.857, 40.286]    20
# 5  (40.286, 47.714]    12
# 4  (47.714, 55.143]    12
# 3  (55.143, 62.571]    14
# 1    (62.571, 70.0]    19

# %%
#Generar columnas siguientes
tabla_frecuencia['Frec Rel'] = tabla_frecuencia['Frec'] / n
tabla_frecuencia['Frec Porc'] = tabla_frecuencia['Frec'] / n * 100
tabla_frecuencia['Frec Ac'] = tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Drec Rel Ac'] = tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Porc Ac'] = tabla_frecuencia['Frec Porc'].cumsum()

#Mostrar la tabla de frecuencia
print(tabla_frecuencia)
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Ac  Drec Rel Ac  \
# 2  (17.948, 25.429]    15      0.15       15.0       15         0.15
# 6  (25.429, 32.857]     8      0.08        8.0       23         0.23
# 0  (32.857, 40.286]    20      0.20       20.0       43         0.43
# 5  (40.286, 47.714]    12      0.12       12.0       55         0.55
# 4  (47.714, 55.143]    12      0.12       12.0       67         0.67
# 3  (55.143, 62.571]    14      0.14       14.0       81         0.81
# 1    (62.571, 70.0]    19      0.19       19.0      100         1.00
#
#    Frec Porc Ac
# 2          15.0
# 6          23.0
# 0          43.0
# 5          55.0
# 4          67.0
# 3          81.0
# 1         100.0

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(edades, alpha = 0.5)
plt.title('Histograma de edades')
# Out:
# Text(0.5, 1.0, 'Histograma de edades')

# %%
#Crea un histograma basado en la tabla de frecuencia
plt.hist(df['Edad'], bins=K, alpha = 0.5)
plt.title('Histograma de edades basado en la regla de Sturges')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
