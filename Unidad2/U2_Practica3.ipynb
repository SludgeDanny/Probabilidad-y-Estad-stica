# %% [markdown]
# <a href="https://colab.research.google.com/github/SludgeDanny/Probabilidad-y-Estad-stica/blob/main/Unidad2/U2_Practica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Probabilidad y Estadistica
# ##Unidad 2
# ##Practica 3
#
# ###Maestro: José Gabriel Rodrigez Rivas
# ###Alumno: Daniel Rosales Reyes

# %%
import math as mt
import matplotlib.pyplot as plt
from itertools import combinations
from itertools import combinations_with_replacement
import numpy as np

# %%
dado = [1, 2, 3, 4, 5, 6]
n = len(dado)
r = 2

CnR = mt.factorial(n+r-1) / (mt.factorial(r)*mt.factorial((n+r-1)-r))
print("Existen", CnR, " posibles combinaciones con repetición del total de ", n, " dados en grupos de ", r, " en ", r)
print("Aqui las combinaciones con repeticiones de los datos: ")

elementos = [1, 2, 3, 4, 5, 6]

r = 2

combinaciones_dados = list(combinations_with_replacement(dado, r))

for combinacion in combinaciones_dados:
    print(combinacion)
# Out:
# Existen 21.0  posibles combinaciones con repetición del total de  6  dados en grupos de  2  en  2
# Aqui las combinaciones con repeticiones de los datos:
# (1, 1)
# (1, 2)
# (1, 3)
# (1, 4)
# (1, 5)
# (1, 6)
# (2, 2)
# (2, 3)
# (2, 4)
# (2, 5)
# (2, 6)
# (3, 3)
# (3, 4)
# (3, 5)
# (3, 6)
# (4, 4)
# (4, 5)
# (4, 6)
# (5, 5)
# (5, 6)
# (6, 6)
