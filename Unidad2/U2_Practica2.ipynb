# %% [markdown]
# <a href="https://colab.research.google.com/github/SludgeDanny/Probabilidad-y-Estad-stica/blob/main/Unidad2/U2_Practica2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Probabilidad y Estadistica
# ##Unidad 2
# ##Practica 1
#
# ###Maestro: José Gabriel Rodrigez Rivas
# ###Alumno: Daniel Rosales Reyes

# %%
import math as mt
import matplotlib.pyplot as plt
from itertools import combinations
from itertools import combinations_with_replacement
import numpy as np

# %%
caracteres = ["A", "B", "C", "D", "E", "F", "0", "1", "2", "3", "4", "5"]
n = len(caracteres)
r = 10

Cn = mt.factorial(n)/(mt.factorial(r)*mt.factorial(n-r))

print("Existen", Cn, " posibles combinaciones sin repetición del total de ", n, " caracteres en grupos de ", r, " en ", r)

print("Aqui las combinaciones: ")
combinaciones_caracteres = list(combinations(caracteres, r))
for combinacion in combinaciones_caracteres:
    print(combinacion)
# Out:
# Existen 66.0  posibles combinaciones sin repetición del total de  12  caracteres en grupos de  10  en  10
# Aqui las combinaciones:
# ('A', 'B', 'C', 'D', 'E', 'F', '0', '1', '2', '3')
# ('A', 'B', 'C', 'D', 'E', 'F', '0', '1', '2', '4')
# ('A', 'B', 'C', 'D', 'E', 'F', '0', '1', '2', '5')
# ('A', 'B', 'C', 'D', 'E', 'F', '0', '1', '3', '4')
# ('A', 'B', 'C', 'D', 'E', 'F', '0', '1', '3', '5')
# ('A', 'B', 'C', 'D', 'E', 'F', '0', '1', '4', '5')
# ('A', 'B', 'C', 'D', 'E', 'F', '0', '2', '3', '4')
# ('A', 'B', 'C', 'D', 'E', 'F', '0', '2', '3', '5')
# ('A', 'B', 'C', 'D', 'E', 'F', '0', '2', '4', '5')
# ('A', 'B', 'C', 'D', 'E', 'F', '0', '3', '4', '5')
# ('A', 'B', 'C', 'D', 'E', 'F', '1', '2', '3', '4')
# ('A', 'B', 'C', 'D', 'E', 'F', '1', '2', '3', '5')
# ('A', 'B', 'C', 'D', 'E', 'F', '1', '2', '4', '5')
# ('A', 'B', 'C', 'D', 'E', 'F', '1', '3', '4', '5')
# ('A', 'B', 'C', 'D', 'E', 'F', '2', '3', '4', '5')
# ('A', 'B', 'C', 'D', 'E', '0', '1', '2', '3', '4')
# ('A', 'B', 'C', 'D', 'E', '0', '1', '2', '3', '5')
# ('A', 'B', 'C', 'D', 'E', '0', '1', '2', '4', '5')
# ('A', 'B', 'C', 'D', 'E', '0', '1', '3', '4', '5')
# ('A', 'B', 'C', 'D', 'E', '0', '2', '3', '4', '5')
# ('A', 'B', 'C', 'D', 'E', '1', '2', '3', '4', '5')
# ('A', 'B', 'C', 'D', 'F', '0', '1', '2', '3', '4')
# ('A', 'B', 'C', 'D', 'F', '0', '1', '2', '3', '5')
# ('A', 'B', 'C', 'D', 'F', '0', '1', '2', '4', '5')
# ('A', 'B', 'C', 'D', 'F', '0', '1', '3', '4', '5')
# ('A', 'B', 'C', 'D', 'F', '0', '2', '3', '4', '5')
# ('A', 'B', 'C', 'D', 'F', '1', '2', '3', '4', '5')
# ('A', 'B', 'C', 'D', '0', '1', '2', '3', '4', '5')
# ('A', 'B', 'C', 'E', 'F', '0', '1', '2', '3', '4')
# ('A', 'B', 'C', 'E', 'F', '0', '1', '2', '3', '5')
# ('A', 'B', 'C', 'E', 'F', '0', '1', '2', '4', '5')
# ('A', 'B', 'C', 'E', 'F', '0', '1', '3', '4', '5')
# ('A', 'B', 'C', 'E', 'F', '0', '2', '3', '4', '5')
# ('A', 'B', 'C', 'E', 'F', '1', '2', '3', '4', '5')
# ('A', 'B', 'C', 'E', '0', '1', '2', '3', '4', '5')
# ('A', 'B', 'C', 'F', '0', '1', '2', '3', '4', '5')
# ('A', 'B', 'D', 'E', 'F', '0', '1', '2', '3', '4')
# ('A', 'B', 'D', 'E', 'F', '0', '1', '2', '3', '5')
# ('A', 'B', 'D', 'E', 'F', '0', '1', '2', '4', '5')
# ('A', 'B', 'D', 'E', 'F', '0', '1', '3', '4', '5')
# ('A', 'B', 'D', 'E', 'F', '0', '2', '3', '4', '5')
# ('A', 'B', 'D', 'E', 'F', '1', '2', '3', '4', '5')
# ('A', 'B', 'D', 'E', '0', '1', '2', '3', '4', '5')
# ('A', 'B', 'D', 'F', '0', '1', '2', '3', '4', '5')
# ('A', 'B', 'E', 'F', '0', '1', '2', '3', '4', '5')
# ('A', 'C', 'D', 'E', 'F', '0', '1', '2', '3', '4')
# ('A', 'C', 'D', 'E', 'F', '0', '1', '2', '3', '5')
# ('A', 'C', 'D', 'E', 'F', '0', '1', '2', '4', '5')
# ('A', 'C', 'D', 'E', 'F', '0', '1', '3', '4', '5')
# ('A', 'C', 'D', 'E', 'F', '0', '2', '3', '4', '5')
# ('A', 'C', 'D', 'E', 'F', '1', '2', '3', '4', '5')
# ('A', 'C', 'D', 'E', '0', '1', '2', '3', '4', '5')
# ('A', 'C', 'D', 'F', '0', '1', '2', '3', '4', '5')
# ('A', 'C', 'E', 'F', '0', '1', '2', '3', '4', '5')
# ('A', 'D', 'E', 'F', '0', '1', '2', '3', '4', '5')
# ('B', 'C', 'D', 'E', 'F', '0', '1', '2', '3', '4')
# ('B', 'C', 'D', 'E', 'F', '0', '1', '2', '3', '5')
# ('B', 'C', 'D', 'E', 'F', '0', '1', '2', '4', '5')
# ('B', 'C', 'D', 'E', 'F', '0', '1', '3', '4', '5')
# ('B', 'C', 'D', 'E', 'F', '0', '2', '3', '4', '5')
# ('B', 'C', 'D', 'E', 'F', '1', '2', '3', '4', '5')
# ('B', 'C', 'D', 'E', '0', '1', '2', '3', '4', '5')
# ('B', 'C', 'D', 'F', '0', '1', '2', '3', '4', '5')
# ('B', 'C', 'E', 'F', '0', '1', '2', '3', '4', '5')
# ('B', 'D', 'E', 'F', '0', '1', '2', '3', '4', '5')
# ('C', 'D', 'E', 'F', '0', '1', '2', '3', '4', '5')
