# %% [markdown]
# <a href="https://colab.research.google.com/github/SludgeDanny/Probabilidad-y-Estad-stica/blob/main/Unidad4/U4_Practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Probabilidad y Estadistica
# ##Unidad 4
# ##Practica 1
#
# ###Maestro: José Gabriel Rodrigez Rivas
# ###Alumno: Daniel Rosales Reyes

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
media = 70
desv_std = 4
num_datos = 500
datos = np.random.normal(media, desv_std, num_datos)
datos[0:50]
# Out:
# array([68.14569223, 71.38306822, 76.69207672, 69.15539012, 63.089758  ,
#        71.59566813, 76.43471917, 60.1662971 , 68.97318448, 72.32800559,
#        69.46196481, 70.94554342, 75.54114593, 61.52155569, 70.11737861,
#        68.59951562, 70.50479783, 71.40353653, 71.93489854, 74.47994484,
#        64.06849283, 59.46280995, 81.75412154, 70.9206994 , 74.66958021,
#        73.25391589, 67.25420549, 81.5296144 , 67.33317655, 67.13411363,
#        66.65911127, 66.70254776, 71.85234668, 64.20872817, 75.87691293,
#        67.51908626, 63.53185345, 72.13817759, 72.30491864, 70.16993241,
#        67.04188036, 75.50348002, 70.62299341, 73.02674168, 70.19646569,
#        76.7178522 , 68.81724078, 69.89972119, 75.06582646, 71.6283818 ])

# %%
x = np.linspace(media - 3 * desv_std + 3 * desv_std, num_datos)

pdf = 1 / (desv_std * np.sqrt(2 * np.pi)) * np.exp(-(x - media) ** 2 / (2 * desv_std ** 2))

# %%
print("Imprimir los primeros 50 valores de x", x[0:50], ", y los primeros 50 pdf", pdf[0:50])
# Out:
# Imprimir los primeros 50 valores de x [ 70.          78.7755102   87.55102041  96.32653061 105.10204082
#  113.87755102 122.65306122 131.42857143 140.20408163 148.97959184
#  157.75510204 166.53061224 175.30612245 184.08163265 192.85714286
#  201.63265306 210.40816327 219.18367347 227.95918367 236.73469388
#  245.51020408 254.28571429 263.06122449 271.83673469 280.6122449
#  289.3877551  298.16326531 306.93877551 315.71428571 324.48979592
#  333.26530612 342.04081633 350.81632653 359.59183673 368.36734694
#  377.14285714 385.91836735 394.69387755 403.46938776 412.24489796
#  421.02040816 429.79591837 438.57142857 447.34693878 456.12244898
#  464.89795918 473.67346939 482.44897959 491.2244898  500.        ] , y los primeros 50 pdf [9.97355701e-002 8.98874312e-003 6.58029940e-006 3.91282234e-011
#  1.88987201e-018 7.41433915e-028 2.36270931e-039 6.11569653e-053
#  1.28581755e-068 2.19588992e-086 3.04606782e-106 3.43215081e-128
#  3.14116642e-152 2.33514213e-178 1.41004666e-206 6.91594349e-237
#  2.75528913e-269 8.91621870e-304 0.00000000e+000 0.00000000e+000
#  0.00000000e+000 0.00000000e+000 0.00000000e+000 0.00000000e+000
#  0.00000000e+000 0.00000000e+000 0.00000000e+000 0.00000000e+000
#  0.00000000e+000 0.00000000e+000 0.00000000e+000 0.00000000e+000
#  0.00000000e+000 0.00000000e+000 0.00000000e+000 0.00000000e+000
#  0.00000000e+000 0.00000000e+000 0.00000000e+000 0.00000000e+000
#  0.00000000e+000 0.00000000e+000 0.00000000e+000 0.00000000e+000
#  0.00000000e+000 0.00000000e+000 0.00000000e+000 0.00000000e+000
#  0.00000000e+000 0.00000000e+000]

# %%
plt.figure(figsize=(6,4))
plt.hist(datos, bins=15, alpha=0.4, color='b')
plt.title('Distribucón normal')
plt.xlabel('Peso en kg de los estudiantes')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.plot(x, pdf, label='Normal:(media:{}; ds:{})'. format(np.round(media, 2), np.round(desv_std, 2)))
plt.title('Funcion de Densidad de Probabilidad (PDF) - Distribucion Normal')
plt.xlabel('Peso en kg de los estudiantes')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.hist(datos, bins=15, alpha=0.4, density=True, color='b')
plt.plot(x, pdf, 'k', linewidth = 2)

plt.title('Distribucion Normal')
plt.xlabel('Peso en kg de los estudiantes')
plt.grid(True)
plt.show()
