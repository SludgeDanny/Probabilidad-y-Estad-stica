# %% [markdown]
# <a href="https://colab.research.google.com/github/SludgeDanny/Probabilidad-y-Estad-stica/blob/main/Unidad3/U3_Proactica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Probabilidad y Estadistica
# ##Unidad 3
# ##Practica 3
#
# ###Maestro: José Gabriel Rodrigez Rivas
# ###Alumno: Daniel Rosales Reyes

# %%
import math

# %%
x = [5, 6, 7, 8, 9, 10]
p = [0.05, 0.10, 0.20, 0.30, 0.25, 0.10]

#Calcular E(x)
esperanza = 0
for i in range(len(x)):
  esperanza += x[i] * p[i]

#Calcular E(x^2)
esperanza_cuadrado = 0
for i in range(len(x)):
  esperanza_cuadrado += (x[i] ** 2) * p[i]

#Calcular varianza y desviacion estándar
varianza = esperanza_cuadrado - esperanza**2
desviacion = math.sqrt(varianza)

#Mostrar resultados
print(f"E(X) = {esperanza:.2f}")
print(f"E(X^2) = {esperanza_cuadrado:.2f}")
print(f"Varianza = {varianza:.2f}")
print(f"Desviación estándar = {desviacion:.2f}")
# Out:
# E(X) = 7.90
# E(X^2) = 64.10
# Varianza = 1.69
# Desviación estándar = 1.30
