# %% [markdown]
# <a href="https://colab.research.google.com/github/SludgeDanny/Probabilidad-y-Estad-stica/blob/main/Unidad3/U3_Practica4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Probabilidad y Estadistica
# ##Unidad 3
# ##Practica 4
#
# ###Maestro: José Gabriel Rodrigez Rivas
# ###Alumno: Daniel Rosales Reyes

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [5, 6, 7, 8, 9, 10]
p = [0.05, 0.10, 0.20, 0.30, 0.25, 0.10]

#Calcular función acumulada
F = np.cumsum(p)

#Mostrar resultados
for xi, fi in zip(x, F):
    print(f"F({xi}) = {fi:.2f}")

#Graficar
plt.step(x, F, where='post')
plt.title('Función de Distribución Acumulada (FDA)')
plt.xlabel("Calidicación")
plt.ylabel("Probabilidad acumulada")
plt.grid(True)
plt.ylim(0, 1.05)
plt.show()
# Out:
# F(5) = 0.05
# F(6) = 0.15
# F(7) = 0.35
# F(8) = 0.65
# F(9) = 0.90
# F(10) = 1.00
