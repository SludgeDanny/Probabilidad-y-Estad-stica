# %% [markdown]
# <a href="https://colab.research.google.com/github/SludgeDanny/Probabilidad-y-Estad-stica/blob/main/Practica_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Probabilidad y Estdistica
# ##Unidad 1
# ###Facilitador: Jose Gabriel Rodriguez Rivas
# ###Alumno: Daniel Rosales Reyes
# ###**Programa 1: Estadistica basica e Histogramas**

# %%
from statistics import *

# %%
#Lista de calificaciones del grupo A de probabilidad y estadistica.
grupos = [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
print (grupos)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]

# %%
# La funcion type nos devolvera el tipo de dato de la variable
type(grupos)
# Out:
# list

# %%
# Sacar la media de las calificaciones con una formula
promedio = sum(grupos) / len(grupos)
print(promedio)
# Out:
# 75.33333333333333

# %%
mediana = median(grupos)
print(mediana)
# Out:
# 76.5

# %%
moda = mode(grupos)
print(moda)
# Out:
# 70

# %%
tiemposlimites = [14.16, 17.20, 14.69, 13.27, 22.15, 18.71, 19.15, 28.65, 15.18, 17.20]
print(tiemposlimites)
promedio = sum(tiemposlimites) / len(tiemposlimites)
print("El tiempo promedio es: ", promedio)

mediana = median(tiemposlimites)
print("El tiempo medio es: ", mediana)

moda = mode(tiemposlimites)
print("La moda es: ", moda)
# Out:
# [14.16, 17.2, 14.69, 13.27, 22.15, 18.71, 19.15, 28.65, 15.18, 17.2]
# El tiempo promedio es:  18.035999999999998
# El tiempo medio es:  17.2
# La moda es:  17.2

# %%
#Libreria para generar numero aleatorios
import random

# %%
fabrica1 = []
for i in range (100):
  numero_aleatorio = round(random.uniform(50,100),2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [86.22, 51.36, 50.44, 93.38, 98.41, 71.75, 69.56, 61.41, 53.03, 69.34, 61.06, 57.65, 54.03, 53.18, 55.74, 87.19, 81.76, 82.33, 74.97, 58.51, 51.46, 61.34, 83.71, 73.79, 86.43, 53.88, 91.86, 97.06, 91.73, 69.47, 58.79, 61.7, 88.34, 94.55, 67.43, 64.4, 89.14, 89.51, 51.23, 67.08, 82.23, 63.78, 63.26, 86.31, 52.85, 83.29, 96.45, 95.04, 85.2, 50.25, 90.23, 82.79, 52.58, 79.24, 76.14, 88.03, 62.97, 84.36, 86.25, 73.56, 58.22, 87.46, 50.56, 54.77, 74.63, 73.09, 64.59, 68.27, 71.47, 93.24, 67.81, 54.07, 62.4, 82.41, 61.27, 66.27, 71.91, 50.89, 64.18, 94.38, 50.72, 76.09, 64.29, 86.26, 60.01, 82.85, 58.66, 86.41, 93.25, 92.81, 77.92, 59.3, 50.65, 96.11, 82.51, 64.81, 91.48, 87.87, 84.62, 96.57]

# %%
fabrica2 = []
for i in range (100):
  numero_aleatorio = round(random.uniform(50,100),2)
  fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [65.54, 82.03, 66.58, 88.61, 64.55, 52.77, 90.78, 73.77, 86.28, 76.36, 69.91, 88.78, 74.26, 91.1, 99.1, 61.42, 93.78, 95.12, 82.74, 57.21, 60.15, 53.71, 67.22, 87.2, 51.17, 81.81, 62.85, 84.38, 62.62, 80.73, 69.38, 87.32, 75.28, 61.78, 75.78, 74.71, 72.25, 91.92, 91.04, 53.49, 57.29, 71.7, 65.89, 83.61, 92.09, 96.09, 71.33, 57.89, 77.26, 86.78, 50.47, 60.92, 63.23, 81.55, 58.3, 64.67, 64.4, 75.16, 55.84, 63.68, 74.17, 74.55, 61.41, 58.15, 96.81, 97.75, 96.9, 55.65, 60.34, 72.66, 81.28, 80.12, 89.76, 84.63, 71.7, 85.81, 57.41, 70.61, 88.08, 79.98, 73.62, 74.81, 56.91, 73.11, 82.48, 64.22, 57.6, 89.21, 96.07, 52.64, 56.44, 66.59, 55.42, 74.21, 52.95, 81.44, 77.05, 79.47, 78.64, 92.0]

# %%
#Libreria de python para graficar valores
import matplotlib.pyplot as plt

# %%
plt.hist(fabrica1)
plt.title("Producción diaria de la fabrica 1")
# Out:
# Text(0.5, 1.0, 'Producción diaria de la fabrica 1')

# %%
plt.hist(fabrica2)
plt.title("Producción diaria de la fabrica 2")
# Out:
# Text(0.5, 1.0, 'Producción diaria de la fabrica 2')

# %%
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

print("Valores de la Fabrica 1")
print("La media es: ", media1)
print("La mediana es: ", mediana1)
print("La moda es: ", moda1)
# Out:
# Valores de la Fabrica 1
# La media es:  74.94856666666666
# La mediana es:  76.07
# La moda es:  51.46

# %%
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

print("Valores de la Fabrica 2")
print("La media es: ", media2)
print("La mediana es: ", mediana2)
print("La moda es: ", moda2)
# Out:
# Valores de la Fabrica 2
# La media es:  73.7628
# La mediana es:  74.19
# La moda es:  71.7

# %%
fig, (ax1, ax2) = plt.subplots(arrows=1, ncols=2, figsize =(19,5) )
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()
